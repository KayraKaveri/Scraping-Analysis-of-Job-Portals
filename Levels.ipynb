# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import numpy as np
import re
import math

# %%
df= pd.read_csv('Edit.csv')

# %%
df2=df
df3=df

# %%
df.shape
# Out:
# (3593, 12)

# %%
df['Level']=np.nan

# %%
df['Level'].value_counts()
# Out:
# Series([], Name: Level, dtype: int64)

# %%
c=df['Job Title']
z=0

for rows in c:
    rows=rows.lower()
    a='senior'
    if(a in rows ):
        df['Level'][z]='Advance'



    z=z+1
# Out:
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_22120\1313492720.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Level'][z]='Advance'

# %%
c=df['Job Title']
z=0

for rows in c:
    rows=rows.lower()
    a='sr'
    if(a in rows ):
        df['Level'][z]='Advance'



    z=z+1

# %%
c=df['Job Title']
z=0

for rows in c:
    rows=rows.lower()
    a='chief'
    if(a in rows ):
        df['Level'][z]='Advance'



    z=z+1

# %%
c=df['Job Title']
z=0

for rows in c:
    rows=rows.lower()
    a='dir'
    if(a in rows ):
        df['Level'][z]='Advance'



    z=z+1

# %%
c=df['Job Title']
z=0

for rows in c:
    rows=rows.lower()
    a='director'
    if(a in rows ):
        df['Level'][z]='Advance'



    z=z+1

# %%
c=df['Job Title']
z=0

for rows in c:
    rows=rows.lower()
    a='principal'
    if(a in rows ):
        df['Level'][z]='Advance'



    z=z+1

# %%
c=df['Job Title']
z=0

for rows in c:
    rows=rows.lower()
    a='lead'
    if(a in rows ):
        df['Level'][z]='Advance'



    z=z+1

# %%
c=df['Job Title']
z=0

for rows in c:
    rows=rows.lower()
    a='associate'
    if(a in rows ):
        df['Level'][z]='Entry'



    z=z+1

# %%
c=df['Job Title']
z=0

for rows in c:
    rows=rows.lower()
    a='intern'
    if(a in rows ):
        df['Level'][z]='Entry'



    z=z+1

# %%
c=df['Job Title']
z=0

for rows in c:
    rows=rows.lower()
    a='internship'
    if(a in rows ):
        df['Level'][z]='Entry'



    z=z+1

# %%
c=df['Job Title']
z=0

for rows in c:
    rows=rows.lower()
    a='fresh'
    if(a in rows ):
        df['Level'][z]='Entry'



    z=z+1

# %%
c=df['Job Title']
z=0

for rows in c:
    rows=rows.lower()
    a='fresher'
    if(a in rows ):
        df['Level'][z]='Entry'



    z=z+1

# %%
c=df['Job Title']
z=0

for rows in c:
    rows=rows.lower()
    a='jr'
    if(a in rows ):
        df['Level'][z]='Entry'



    z=z+1

# %%
c=df['Job Title']
z=0

for rows in c:
    rows=rows.lower()
    a='junior'
    if(a in rows ):
        df['Level'][z]='Entry'



    z=z+1

# %%
c=df['Job Title']
z=0

for rows in c:
    rows=rows.lower()
    a='trainee'
    if(a in rows ):
        df['Level'][z]='Entry'



    z=z+1

# %%
c=df['Job Title']
z=0

for rows in c:
    rows=rows.lower()
    a='trainer'
    if(a in rows ):
        df['Level'][z]='Entry'



    z=z+1

# %%
c=df['Job Title']
z=0

for rows in c:
    rows=rows.lower()
    a='assistant'
    if(a in rows ):
        df['Level'][z]='Entry'



    z=z+1

# %%
c=df['Job Title']
z=0

for rows in c:
    rows=rows.lower()

    if(type(df['Level'][z] )== float):
        df['Level'][z]='Mid'



    z=z+1

# %%
df.isna().sum()
# Out:
# Unnamed: 0.1              0
# Unnamed: 0                0
# Company Name              0
# Job Title                 0
# salary_period          1658
# Average                1658
# Job Description           0
# Years of Experience    2031
# Location                123
# Job Type                  0
# Rating                    0
# Categories                0
# Level                     0
# dtype: int64

# %%
df.to_csv('Edit2.csv')

# %%
# Out:
#       Unnamed: 0.1  Unnamed: 0                      Company Name  \
# 0                0           0  Larsen & Toubro Infotech Limited
# 1                1           1                          Deloitte
# 2                2           2         Flairmid Software Pvt Ltd
# 3                3           3                             Shell
# 4                4           4    Brimming Grace Capital Pvt Ltd
# ...            ...         ...                               ...
# 3588          3728        1899                         sharechat
# 3589          3729        1900                Accord Consultants
# 3590          3730        1901                          Barclays
# 3591          3731        1902                            Diageo
# 3592          3732        1903                 Colgate-Palmolive
#
#                                               Job Title salary_period  \
# 0                                          Data Science          year
# 1     Senior Analyst- Research & Insights- Data Scie...          year
# 2                                 Junior Data Scientist          year
# 3                              Associate Data Scientist          year
# 4                                 Data Scientist Intern          year
# ...                                                 ...           ...
# 3588                     Lead Machine Learning Engineer           NaN
# 3589                                     Data Scientist           NaN
# 3590  Director, Operational Risk Reporting & Data An...           NaN
# 3591                 Manager- Machine Learning Engineer           NaN
# 3592   Supply Chain Network Data & Analytics Specialist           NaN
#
#       Average                                    Job Description  \
# 0         6.5    Job Location Mumbai            Job Descripti...
# 1         6.5    Job Location Bhopal            Job Descripti...
# 2         2.0    Job Location Katha Baddi            Job Desc...
# 3        15.0        At Boeing  we innovate and collaborate t...
# 4        11.0    Our client Successful SA technology group is...
# ...       ...                                                ...
# 3588      NaN  Machine Learning Engineer    ML Platform    Th...
# 3589      NaN   We are looking for a rare hybrid: a statistic...
# 3590      NaN        Job Title:    Director  Operational Risk...
# 3591      NaN      Job Description :    Bachelor’s degree  B ...
# 3592      NaN   Relocation Assistance Offered Within Country ...
#
#       Years of Experience                                    Location  \
# 0                     NaN                                      Mumbai
# 1                     NaN                                   Hyderābād
# 2                     1.0                                        Pune
# 3                     NaN                                     Chennai
# 4                     5.0                                     Gurgaon
# ...                   ...                                         ...
# 3588                  NaN  Temporarily Remote in Bengaluru, Karnataka
# 3589                  NaN                           Pune, Maharashtra
# 3590                  NaN                        Noida, Uttar Pradesh
# 3591                  NaN                        Bengaluru, Karnataka
# 3592                  NaN                         Mumbai, Maharashtra
#
#        Job Type  Rating      Categories    Level
# 0     Full time     3.8  Data Scientist      Mid
# 1     Full time     4.1  Data Scientist  Advance
# 2     Full time     4.2  Data Scientist    Entry
# 3     Full time     4.1  Data Scientist    Entry
# 4     Part time     4.2  Data Scientist    Entry
# ...         ...     ...             ...      ...
# 3588  Full time     3.8   AI Specialist  Advance
# 3589  Full time     4.8  Data Scientist      Mid
# 3590  Full time     3.9    Data Analyst  Advance
# 3591  Full time     4.0   AI Specialist      Mid
# 3592  Full time     4.3   AI Specialist      Mid
#
# [3593 rows x 13 columns]
