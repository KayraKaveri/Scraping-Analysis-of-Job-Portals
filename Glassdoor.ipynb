# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import numpy as np
import re

# %%
df= pd.read_csv('abhi.csv')
df2=df
df3=df

# %%
df2
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0                          Machine Learning Engineer
# 1              1                            Staff Software Engineer
# 2              2                                    IoT Engineer -1
# 3              3          Graduate Engineering Trainee (Electrical)
# 4              4                                     Card Analytics
# ...          ...                                                ...
# 1346        1346  Lead Structural Analysis Engineer - Service En...
# 1347        1347                                   Python Developer
# 1348        1348                                 Engagement Manager
# 1349        1349                        Software Engineer II - Data
# 1350        1350                                                NaN
#
#      Salary Estimate                                        Job Snippet  \
# 0                NaN  Design and development of machine learning mod...
# 1                NaN  NL methodology: grammar-based, data-driven and...
# 2                NaN  Rockwell Automation is a global technology lea...
# 3                NaN  Yulu is looking for a Proactive and dynamic in...
# 4                NaN  Working knowledge of advanced statistical conc...
# ...              ...                                                ...
# 1346             NaN  Responsible for performing structural analysis...
# 1347             NaN  Expertise is machine learning, deep learning a...
# 1348             NaN  Talent Acquisition and Talent Management need....
# 1349             NaN  Design and develop new systems to empower fast...
# 1350             NaN                                                NaN
#
#                         Job Type  Rating                    Company Name  \
# 0                             []     NaN                   Intangles Lab
# 1                             []     3.9                   GE Healthcare
# 2                  ['Full-time']     3.8             Rockwell Automation
# 3                    ['Fresher']     NaN                            Yulu
# 4     ['Regular / Permanent +1']     3.8       JPMorgan Chase Bank, N.A.
# ...                          ...     ...                             ...
# 1346                          []     3.9                          BOEING
# 1347                          []     3.9  TATA Consultancy Services Ltd.
# 1348                          []     NaN                    Eightfold.AI
# 1349               ['Full-time']     3.6                            Uber
# 1350                          []     NaN                             NaN
#
#                                         Location  \
# 0                              Pune, Maharashtra
# 1                           Bengaluru, Karnataka
# 2                              Pune, Maharashtra
# 3                           Bengaluru, Karnataka
# 4                            Mumbai, Maharashtra
# ...                                          ...
# 1346                        Bengaluru, Karnataka
# 1347                        Hyderabad, Telangana
# 1348                                         NaN
# 1349  Temporarily Remote in Bengaluru, Karnataka
# 1350                                         NaN
#
#                                                   Links  \
# 0     https://in.indeed.com/rc/clk?jk=756206bc8387a0...
# 1     https://in.indeed.com/rc/clk?jk=bffcbdceb192c5...
# 2     https://in.indeed.com/rc/clk?jk=274acf5bfda5fe...
# 3     https://in.indeed.com/rc/clk?jk=981169770cc503...
# 4     https://in.indeed.com/rc/clk?jk=7c80924698519a...
# ...                                                 ...
# 1346  https://in.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 1347  https://in.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 1348  https://in.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 1349  https://in.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 1350                                                NaN
#
#                                         Job Description
# 0     \nDepartment :- Analytics\n Type :- Work from ...
# 1     \nJob Description Summary In depth understandi...
# 2     Rockwell Automation is a global technology lea...
# 3     \nAbout Yulu Are you sick of breathing poor qu...
# 4     \n JPMorgan Chase & Co. (NYSE: JPM) is a leadi...
# ...                                                 ...
# 1346  \n\nAt Boeing, we innovate and collaborate to ...
# 1347  Expertise is machine learning, deep learning a...
# 1348  \n\nAbout Eightfold \n\n\n  Eightfold was foun...
# 1349  \n\n  The Global Intelligence Team focuses on ...
# 1350                                                NaN
#
# [1351 rows x 10 columns]

# %%
df3.replace('None', np.nan)
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0                          Machine Learning Engineer
# 1              1                            Staff Software Engineer
# 2              2                                    IoT Engineer -1
# 3              3          Graduate Engineering Trainee (Electrical)
# 4              4                                     Card Analytics
# ...          ...                                                ...
# 1346        1346  Lead Structural Analysis Engineer - Service En...
# 1347        1347                                   Python Developer
# 1348        1348                                 Engagement Manager
# 1349        1349                        Software Engineer II - Data
# 1350        1350                                                NaN
#
#      Salary Estimate                                        Job Snippet  \
# 0                NaN  Design and development of machine learning mod...
# 1                NaN  NL methodology: grammar-based, data-driven and...
# 2                NaN  Rockwell Automation is a global technology lea...
# 3                NaN  Yulu is looking for a Proactive and dynamic in...
# 4                NaN  Working knowledge of advanced statistical conc...
# ...              ...                                                ...
# 1346             NaN  Responsible for performing structural analysis...
# 1347             NaN  Expertise is machine learning, deep learning a...
# 1348             NaN  Talent Acquisition and Talent Management need....
# 1349             NaN  Design and develop new systems to empower fast...
# 1350             NaN                                                NaN
#
#                         Job Type  Rating                    Company Name  \
# 0                             []     NaN                   Intangles Lab
# 1                             []     3.9                   GE Healthcare
# 2                  ['Full-time']     3.8             Rockwell Automation
# 3                    ['Fresher']     NaN                            Yulu
# 4     ['Regular / Permanent +1']     3.8       JPMorgan Chase Bank, N.A.
# ...                          ...     ...                             ...
# 1346                          []     3.9                          BOEING
# 1347                          []     3.9  TATA Consultancy Services Ltd.
# 1348                          []     NaN                    Eightfold.AI
# 1349               ['Full-time']     3.6                            Uber
# 1350                          []     NaN                             NaN
#
#                                         Location  \
# 0                              Pune, Maharashtra
# 1                           Bengaluru, Karnataka
# 2                              Pune, Maharashtra
# 3                           Bengaluru, Karnataka
# 4                            Mumbai, Maharashtra
# ...                                          ...
# 1346                        Bengaluru, Karnataka
# 1347                        Hyderabad, Telangana
# 1348                                         NaN
# 1349  Temporarily Remote in Bengaluru, Karnataka
# 1350                                         NaN
#
#                                                   Links  \
# 0     https://in.indeed.com/rc/clk?jk=756206bc8387a0...
# 1     https://in.indeed.com/rc/clk?jk=bffcbdceb192c5...
# 2     https://in.indeed.com/rc/clk?jk=274acf5bfda5fe...
# 3     https://in.indeed.com/rc/clk?jk=981169770cc503...
# 4     https://in.indeed.com/rc/clk?jk=7c80924698519a...
# ...                                                 ...
# 1346  https://in.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 1347  https://in.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 1348  https://in.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 1349  https://in.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 1350                                                NaN
#
#                                         Job Description
# 0     \nDepartment :- Analytics\n Type :- Work from ...
# 1     \nJob Description Summary In depth understandi...
# 2     Rockwell Automation is a global technology lea...
# 3     \nAbout Yulu Are you sick of breathing poor qu...
# 4     \n JPMorgan Chase & Co. (NYSE: JPM) is a leadi...
# ...                                                 ...
# 1346  \n\nAt Boeing, we innovate and collaborate to ...
# 1347  Expertise is machine learning, deep learning a...
# 1348  \n\nAbout Eightfold \n\n\n  Eightfold was foun...
# 1349  \n\n  The Global Intelligence Team focuses on ...
# 1350                                                NaN
#
# [1351 rows x 10 columns]

# %%
df3 = df3.dropna(subset=['Job Title'])

# %%
df3=df3.drop_duplicates()

# %%
df3.shape
# Out:
# (1127, 10)

# %%
df3['Salary Estimate'].value_counts()
# Out:
# ₹14,00,000 - ₹18,00,000 a year    4
# From ₹10,000 a month              4
# ₹3,00,000 - ₹9,00,000 a year      3
# ₹20,000 - ₹40,000 a month         2
# ₹7,00,000 - ₹12,00,000 a year     2
#                                  ..
# ₹50,000 - ₹80,000 a month         1
# ₹5,00,000 - ₹6,50,000 a year      1
# ₹4,20,000 - ₹8,00,000 a year      1
# ₹3,75,354 - ₹14,26,145 a year     1
# ₹10,000 - ₹18,000 a month         1
# Name: Salary Estimate, Length: 127, dtype: int64

# %%
df3['Salary Estimate'] = df3['Salary Estimate'].str.replace('\n', '')
df3['Salary Estimate'] = df3['Salary Estimate'].str.replace(',', '')
df3['Salary Estimate'] = df3['Salary Estimate'].str.replace('₹','')

# %%
df3['Salary Estimate'].value_counts()
# Out:
# 1400000 - 1800000 a year    4
# From 10000 a month          4
# 300000 - 900000 a year      3
# 20000 - 40000 a month       2
# 700000 - 1200000 a year     2
#                            ..
# 50000 - 80000 a month       1
# 500000 - 650000 a year      1
# 420000 - 800000 a year      1
# 375354 - 1426145 a year     1
# 10000 - 18000 a month       1
# Name: Salary Estimate, Length: 127, dtype: int64

# %%
df3=df3.drop(['Job Snippet'],axis=1)

# %%
df3=df3.drop(['Links'],axis=1)

# %%
df3["salary_period"]=np.nan

# %%
import string
df3["Salary Estimate"].str.contains("year")
c=df3["Salary Estimate"]
i=0
for rows in c:
    av=0
    if(type(rows)==str):
        rows=rows.split()
        for item in rows:
            if(item == 'year'):
                df3["salary_period"][i]="year"
        
    i=i+1
# Out:
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_10220\1319600399.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["salary_period"][i]="year"
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_10220\1319600399.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["salary_period"][i]="year"
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_10220\1319600399.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["salary_period"][i]="year"
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_10220\1319600399.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["salary_period"][i]="year"
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_10220\1319600399.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["salary_period"][i]="year"
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_10220\1319600399.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["salary_period"][i]="year"
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_10220\1319600399.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["salary_period"][i]="year"
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_10220\1319600399.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["salary_period"][i]="year"
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_10220\1319600399.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["salary_period"][i]="year"
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_10220\1319600399.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["salary_period"][i]="year"
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_10220\1319600399.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["salary_period"][i]="year"
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_10220\1319600399.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["salary_period"][i]="year"
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_10220\1319600399.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["salary_period"][i]="year"
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_10220\1319600399.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["salary_period"][i]="year"
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_10220\1319600399.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["salary_period"][i]="year"
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_10220\1319600399.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["salary_period"][i]="year"
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_10220\1319600399.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["salary_period"][i]="year"
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_10220\1319600399.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["salary_period"][i]="year"
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_10220\1319600399.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["salary_period"][i]="year"
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_10220\1319600399.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["salary_period"][i]="year"
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_10220\1319600399.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["salary_period"][i]="year"

# %%
import string
df3["Salary Estimate"].str.contains("month")
c=df3["Salary Estimate"]
i=0
for rows in c:
    av=0
    if(type(rows)==str):
        rows=rows.split()
        for item in rows:
            if(item == 'month'):
                df3["salary_period"][i]="month"
        
    i=i+1
# Out:
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_10220\1797335305.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["salary_period"][i]="month"
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_10220\1797335305.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["salary_period"][i]="month"
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_10220\1797335305.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["salary_period"][i]="month"
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_10220\1797335305.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["salary_period"][i]="month"
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_10220\1797335305.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["salary_period"][i]="month"
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_10220\1797335305.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["salary_period"][i]="month"
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_10220\1797335305.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["salary_period"][i]="month"
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_10220\1797335305.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["salary_period"][i]="month"

# %%
import string
df3["Salary Estimate"].str.contains("hour")
c=df3["Salary Estimate"]
i=0
for rows in c:
    av=0
    if(type(rows)==str):
        rows=rows.split()
        for item in rows:
            if(item == 'hour'):
                df3["salary_period"][i]="hour"
        
    i=i+1
# Out:
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_10220\19185784.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["salary_period"][i]="hour"

# %%
df3.to_csv('a2.csv')

# %%
df3["salary_period"].value_counts()
# Out:
# year     102
# month     43
# hour       2
# Name: salary_period, dtype: int64

# %%
df3["Salary Estimate"].value_counts()
# Out:
# 1400000 - 1800000 a year    4
# From 10000 a month          4
# 300000 - 900000 a year      3
# 20000 - 40000 a month       2
# 700000 - 1200000 a year     2
#                            ..
# 50000 - 80000 a month       1
# 500000 - 650000 a year      1
# 420000 - 800000 a year      1
# 375354 - 1426145 a year     1
# 10000 - 18000 a month       1
# Name: Salary Estimate, Length: 127, dtype: int64

# %%
df3["Average"]=np.nan

# %%
c=df3["Salary Estimate"]

av=0
a=0
b=0
i=0
for rows in c:
    av=0
    if(type(rows)==str):
        rows=rows.split()
        for item in rows:
            if(item.isdigit()):
                av=av+1
        if(av==1):
            for char in rows:
                if(char.isdigit()):
                    df3["Average"][i]=char               
    i=i+1
# Out:
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_37012\2560728798.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["Average"][i]=char

# %%
df3["Average"].value_counts()
# Out:
# 10000        5
# 600000.0     4
# 1600000.0    4
# 550000.0     3
# 850000.0     3
#             ..
# 26491.0      1
# 1800000.0    1
# 7000         1
# 115000.0     1
# 3050000.0    1
# Name: Average, Length: 102, dtype: int64

# %%
c=df3["Salary Estimate"]
i=0
for rows in c:
    if(type(rows)==str):
        
        c[i]=c[i].replace(',','')
        c[i]=c[i].replace('-','')
    i=i+1
# Out:
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_37012\822375046.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c[i]=c[i].replace(',','')
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_37012\822375046.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c[i]=c[i].replace('-','')

# %%
def avg(a,b):
    return (a+b)/2
c=df3["Salary Estimate"]

av=0
a=0
b=0
i=0
for rows in c:
    if(type(rows)==str):
        rows=rows.split()
        for item in range(0,len(rows)):
            if(rows[item].isdigit() and rows[item+1].isdigit()):
                av=avg(int(rows[0]),int(rows[1]))
                df3["Average"][i]=av
    i=i+1

# %%
cleaning_list = ['+', '$','/',',','?','.',';','-','@','!','&','%','^','*',')','(', '\n']
for item in cleaning_list:
    df3['Job Description'] = df3['Job Description'].str.replace(item, ' ')
# Out:
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_37012\1660340981.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df3['Job Description'] = df3['Job Description'].str.replace(item, ' ')

# %%
df3['Job Description']
# Out:
# 0        Department :  Analytics  Type :  Work from Of...
# 1        Job Description Summary In depth understandin...
# 2       Rockwell Automation is a global technology lea...
# 3        About Yulu Are you sick of breathing poor qua...
# 4         JPMorgan Chase   Co   NYSE: JPM  is a leadin...
#                               ...
# 1122      At Boeing  we innovate and collaborate to ma...
# 1123      At Boeing  we innovate and collaborate to ma...
# 1124    Expertise is machine learning  deep learning a...
# 1125      About Eightfold      Eightfold was founded w...
# 1126        The Global Intelligence Team focuses on im...
# Name: Job Description, Length: 1127, dtype: object

# %%
exp=[]

# %%
def desc(i):
    l = df3["Job Description"][i]
    p = l.split('\n')
    return p

# %%
for i in range(0,1127):
    
    p=desc(i)
    for line in p:
        y = re.findall('\d+ .+ [Ee]xperience', line)
        if y!= []:
            exp.append(y)

# %%
len(exp)
# Out:
# 999

# %%
df3["desc"]=df3["Job Description"]

# %%
df3
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0                          Machine Learning Engineer
# 1              1                            Staff Software Engineer
# 2              2                                    IoT Engineer -1
# 3              3          Graduate Engineering Trainee (Electrical)
# 4              4                                     Card Analytics
# ...          ...                                                ...
# 1122        1345        Associate Automated Test Equipment Engineer
# 1123        1346  Lead Structural Analysis Engineer - Service En...
# 1124        1347                                   Python Developer
# 1125        1348                                 Engagement Manager
# 1126        1349                        Software Engineer II - Data
#
#      Salary Estimate                    Job Type  Rating  \
# 0                NaN                          []     NaN
# 1                NaN                          []     3.9
# 2                NaN               ['Full-time']     3.8
# 3                NaN                 ['Fresher']     NaN
# 4                NaN  ['Regular / Permanent +1']     3.8
# ...              ...                         ...     ...
# 1122             NaN                          []     3.9
# 1123             NaN                          []     3.9
# 1124             NaN                          []     3.9
# 1125             NaN                          []     NaN
# 1126             NaN               ['Full-time']     3.6
#
#                         Company Name  \
# 0                      Intangles Lab
# 1                      GE Healthcare
# 2                Rockwell Automation
# 3                               Yulu
# 4          JPMorgan Chase Bank, N.A.
# ...                              ...
# 1122                          BOEING
# 1123                          BOEING
# 1124  TATA Consultancy Services Ltd.
# 1125                    Eightfold.AI
# 1126                            Uber
#
#                                         Location  \
# 0                              Pune, Maharashtra
# 1                           Bengaluru, Karnataka
# 2                              Pune, Maharashtra
# 3                           Bengaluru, Karnataka
# 4                            Mumbai, Maharashtra
# ...                                          ...
# 1122                        Bengaluru, Karnataka
# 1123                        Bengaluru, Karnataka
# 1124                        Hyderabad, Telangana
# 1125                                         NaN
# 1126  Temporarily Remote in Bengaluru, Karnataka
#
#                                         Job Description salary_period Average  \
# 0      Department :  Analytics  Type :  Work from Of...           NaN     NaN
# 1      Job Description Summary In depth understandin...           NaN     NaN
# 2     Rockwell Automation is a global technology lea...           NaN     NaN
# 3      About Yulu Are you sick of breathing poor qua...           NaN     NaN
# 4       JPMorgan Chase   Co   NYSE: JPM  is a leadin...           NaN     NaN
# ...                                                 ...           ...     ...
# 1122    At Boeing  we innovate and collaborate to ma...           NaN     NaN
# 1123    At Boeing  we innovate and collaborate to ma...           NaN     NaN
# 1124  Expertise is machine learning  deep learning a...           NaN     NaN
# 1125    About Eightfold      Eightfold was founded w...           NaN     NaN
# 1126      The Global Intelligence Team focuses on im...           NaN     NaN
#
#                                                    desc
# 0      Department :  Analytics  Type :  Work from Of...
# 1      Job Description Summary In depth understandin...
# 2     Rockwell Automation is a global technology lea...
# 3      About Yulu Are you sick of breathing poor qua...
# 4       JPMorgan Chase   Co   NYSE: JPM  is a leadin...
# ...                                                 ...
# 1122    At Boeing  we innovate and collaborate to ma...
# 1123    At Boeing  we innovate and collaborate to ma...
# 1124  Expertise is machine learning  deep learning a...
# 1125    About Eightfold      Eightfold was founded w...
# 1126      The Global Intelligence Team focuses on im...
#
# [1127 rows x 11 columns]

# %%
c=df3["desc"]
d=0
i=0
for rows in c:
    if(type(rows)==str):
        rows=rows.lower()
        rows=rows.split()
        a='years'
        b='experience'
        if a not in rows and b not in rows:
            df3["desc"][i]=None
    i=i+1
# Out:
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_37012\1651435494.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["desc"][i]=None

# %%
d
# Out:
# 60

# %%
c=df3["desc"]
d=0
i=0
for rows in c:
    if(type(rows)==str):
        rows=rows.lower()
        rows=rows.split()
        a='years'
        b='experience'
        if a in rows and b in rows:
            d=d+1
        else:
            df3["desc"][i]=None
    i=i+1
# Out:
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_37012\2791768726.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["desc"][i]=None

# %%
exp2 = pd.DataFrame(exp)

# %%
exp2
# Out:
#                                                      0
# 0    2 0 paradigm   We are innovating at the inters...
# 1    2 6 trillion and operations worldwide  The fir...
# 2    2 6 trillion and operations worldwide  The fir...
# 3    2 0 paradigm   We are innovating at the inters...
# 4    2   6 years      Location Mumbai Bangalore Tri...
# ..                                                 ...
# 994  75 years  People at Boeing have been supportin...
# 995  75 years  People at Boeing have been supportin...
# 996  75 years  People at Boeing have been supportin...
# 997  410 million in funding and a valuation of over...
# 998  10  years of experience in software engineerin...
#
# [999 rows x 1 columns]

# %%
c=exp2[0]
i=0
d=0
k=[]
for rows in c:
    
    if(type(rows)==str):
        rows=rows.lower()
        rows=rows.split()
        
        a='years'
        c='year'
        b='experience'
        if (a in rows or c in rows) and b in rows:
            for t in range(0,len(rows)):
                if(rows[t].isdigit()):
                    if(int(rows[t])<=20):                
                        if(rows[t+1]=='years' or rows[t+1]=='year' or rows[t-1]=='year' or rows[t-1]=='years'):
                            exp2[0][i]=int(rows[t])
                    else:
                        exp2[0][i]=None
        else:
            exp2[0][i]=None
            
    i=i+1

# %%
c=exp2[0]
i=0
d=0
k=[]
for rows in c:
    
    if(type(rows)==str):
        rows=rows.lower()
        rows=rows.split()
        
        a='years'
        c='year'
        b='experience'
        if (a in rows or c in rows) and b in rows:
            for t in range(0,len(rows)):
                if(rows[t].isdigit()):
                    if(int(rows[t])<=20):                
                        if(rows[t+2]=='years' or rows[t+2]=='year' ):
                            exp2[0][i]=int(rows[t])
                    else:
                        exp2[0][i]=None
        else:
            exp2[0][i]=None
            
    i=i+1

# %%
exp2
# Out:
#         0
# 0       1
# 1       4
# 2    None
# 3       2
# 4       6
# ..    ...
# 994    11
# 995  None
# 996    12
# 997     8
# 998    10
#
# [999 rows x 1 columns]

# %%
df3["Years of Experience"]=exp2

# %%
df3["Years of Experience"].value_counts()
# Out:
# 5     129
# 3      93
# 2      79
# 4      56
# 8      54
# 10     50
# 6      49
# 7      35
# 12     31
# 1      28
# 11      9
# 9       7
# 20      5
# 15      5
# 13      3
# 14      3
# 16      2
# 0       2
# 18      1
# Name: Years of Experience, dtype: int64

# %%
df3['Job Type'].value_counts()
# Out:
# []                                                                                 456
# ['Full-time']                                                                      344
# ['Regular / Permanent +1']                                                          56
# ['Regular / Permanent']                                                             30
# ['Full-time +1']                                                                    27
#                                                                                   ...
# ['₹8,00,000 - ₹18,00,000 a year', 'Full-time', 'Flexible shift +1']                  1
# ['Regular / Permanent +1', 'Rotational shift']                                       1
# ['₹7,00,000 - ₹14,00,000 a year', 'Regular / Permanent +1', 'Morning shift +3']      1
# ['₹80,000 - ₹1,50,000 a month', 'Full-time', 'Day shift']                            1
# ['₹10,000 - ₹18,000 a month', 'Fresher +1', 'Fixed shift']                           1
# Name: Job Type, Length: 180, dtype: int64

# %%
kk=[]
c=df3["Job Title"]
i=0
for rows in c:
    if(type(rows)==str):
        rows=rows.lower()
        rows=rows.split()
        a='trainee'
        b='trainer'
        c='intern'
        d='fresher'
        e='internship'
            
        if a in rows or b in rows or c in rows or d in rows or d in rows or e in rows:
            df3["Job Type"][i] = "Part time"
        else:
            df3["Job Type"][i] = "Full time"
    i=i+1
# Out:
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_37012\447312410.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["Job Type"][i] = "Full time"
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_37012\447312410.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["Job Type"][i] = "Part time"

# %%
df3["Job Type"].value_counts()
# Out:
# Full time    1091
# Part time      36
# Name: Job Type, dtype: int64

# %%
c=df3["Job Title"]
i=0
for rows in c:
    if(type(rows)==str):
        
        c[i]=c[i].replace('-','')
        
        
    i=i+1
# Out:
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_37012\3627227692.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c[i]=c[i].replace('-','')

# %%
df3
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0                          Machine Learning Engineer
# 1              1                            Staff Software Engineer
# 2              2                                     IoT Engineer 1
# 3              3          Graduate Engineering Trainee (Electrical)
# 4              4                                     Card Analytics
# ...          ...                                                ...
# 1122        1345        Associate Automated Test Equipment Engineer
# 1123        1346  Lead Structural Analysis Engineer  Service Eng...
# 1124        1347                                   Python Developer
# 1125        1348                                 Engagement Manager
# 1126        1349                         Software Engineer II  Data
#
#      Salary Estimate   Job Type  Rating                    Company Name  \
# 0                NaN  Full time     NaN                   Intangles Lab
# 1                NaN  Full time     3.9                   GE Healthcare
# 2                NaN  Full time     3.8             Rockwell Automation
# 3                NaN  Part time     NaN                            Yulu
# 4                NaN  Full time     3.8       JPMorgan Chase Bank, N.A.
# ...              ...        ...     ...                             ...
# 1122             NaN  Full time     3.9                          BOEING
# 1123             NaN  Full time     3.9                          BOEING
# 1124             NaN  Full time     3.9  TATA Consultancy Services Ltd.
# 1125             NaN  Full time     NaN                    Eightfold.AI
# 1126             NaN  Full time     3.6                            Uber
#
#                                         Location  \
# 0                              Pune, Maharashtra
# 1                           Bengaluru, Karnataka
# 2                              Pune, Maharashtra
# 3                           Bengaluru, Karnataka
# 4                            Mumbai, Maharashtra
# ...                                          ...
# 1122                        Bengaluru, Karnataka
# 1123                        Bengaluru, Karnataka
# 1124                        Hyderabad, Telangana
# 1125                                         NaN
# 1126  Temporarily Remote in Bengaluru, Karnataka
#
#                                         Job Description salary_period Average  \
# 0      Department :  Analytics  Type :  Work from Of...           NaN     NaN
# 1      Job Description Summary In depth understandin...           NaN     NaN
# 2     Rockwell Automation is a global technology lea...           NaN     NaN
# 3      About Yulu Are you sick of breathing poor qua...           NaN     NaN
# 4       JPMorgan Chase   Co   NYSE: JPM  is a leadin...           NaN     NaN
# ...                                                 ...           ...     ...
# 1122    At Boeing  we innovate and collaborate to ma...           NaN     NaN
# 1123    At Boeing  we innovate and collaborate to ma...           NaN     NaN
# 1124  Expertise is machine learning  deep learning a...           NaN     NaN
# 1125    About Eightfold      Eightfold was founded w...           NaN     NaN
# 1126      The Global Intelligence Team focuses on im...           NaN     NaN
#
#                                                    desc Years of Experience
# 0      Department :  Analytics  Type :  Work from Of...                   1
# 1                                                  None                   4
# 2                                                  None                None
# 3      About Yulu Are you sick of breathing poor qua...                   2
# 4       JPMorgan Chase   Co   NYSE: JPM  is a leadin...                   6
# ...                                                 ...                 ...
# 1122    At Boeing  we innovate and collaborate to ma...                 NaN
# 1123    At Boeing  we innovate and collaborate to ma...                 NaN
# 1124  Expertise is machine learning  deep learning a...                 NaN
# 1125    About Eightfold      Eightfold was founded w...                 NaN
# 1126      The Global Intelligence Team focuses on im...                 NaN
#
# [1127 rows x 12 columns]

# %%
df3=df3.drop(['Unnamed: 0'],axis=1)

# %%
df3.to_csv('new3.csv')

# %%
df3=df3.drop(['desc'],axis=1)

# %%
df3
# Out:
#                                               Job Title Salary Estimate  \
# 0                             Machine Learning Engineer             NaN
# 1                               Staff Software Engineer             NaN
# 2                                        IoT Engineer 1             NaN
# 3             Graduate Engineering Trainee (Electrical)             NaN
# 4                                        Card Analytics             NaN
# ...                                                 ...             ...
# 1122        Associate Automated Test Equipment Engineer             NaN
# 1123  Lead Structural Analysis Engineer  Service Eng...             NaN
# 1124                                   Python Developer             NaN
# 1125                                 Engagement Manager             NaN
# 1126                         Software Engineer II  Data             NaN
#
#        Job Type  Rating                    Company Name  \
# 0     Full time     NaN                   Intangles Lab
# 1     Full time     3.9                   GE Healthcare
# 2     Full time     3.8             Rockwell Automation
# 3     Part time     NaN                            Yulu
# 4     Full time     3.8       JPMorgan Chase Bank, N.A.
# ...         ...     ...                             ...
# 1122  Full time     3.9                          BOEING
# 1123  Full time     3.9                          BOEING
# 1124  Full time     3.9  TATA Consultancy Services Ltd.
# 1125  Full time     NaN                    Eightfold.AI
# 1126  Full time     3.6                            Uber
#
#                                         Location  \
# 0                              Pune, Maharashtra
# 1                           Bengaluru, Karnataka
# 2                              Pune, Maharashtra
# 3                           Bengaluru, Karnataka
# 4                            Mumbai, Maharashtra
# ...                                          ...
# 1122                        Bengaluru, Karnataka
# 1123                        Bengaluru, Karnataka
# 1124                        Hyderabad, Telangana
# 1125                                         NaN
# 1126  Temporarily Remote in Bengaluru, Karnataka
#
#                                         Job Description salary_period Average  \
# 0      Department :  Analytics  Type :  Work from Of...           NaN     NaN
# 1      Job Description Summary In depth understandin...           NaN     NaN
# 2     Rockwell Automation is a global technology lea...           NaN     NaN
# 3      About Yulu Are you sick of breathing poor qua...           NaN     NaN
# 4       JPMorgan Chase   Co   NYSE: JPM  is a leadin...           NaN     NaN
# ...                                                 ...           ...     ...
# 1122    At Boeing  we innovate and collaborate to ma...           NaN     NaN
# 1123    At Boeing  we innovate and collaborate to ma...           NaN     NaN
# 1124  Expertise is machine learning  deep learning a...           NaN     NaN
# 1125    About Eightfold      Eightfold was founded w...           NaN     NaN
# 1126      The Global Intelligence Team focuses on im...           NaN     NaN
#
#      Years of Experience
# 0                      1
# 1                      4
# 2                   None
# 3                      2
# 4                      6
# ...                  ...
# 1122                 NaN
# 1123                 NaN
# 1124                 NaN
# 1125                 NaN
# 1126                 NaN
#
# [1127 rows x 10 columns]
