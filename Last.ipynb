# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import numpy as np
import re
import random

# %%
df3= pd.read_csv('white4.csv')

# %%
df3.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                   Company Name  \
# 0             0           0                         Google
# 1             1           1               Procter & Gamble
# 2             2           2              Andaze Japan Ltd.
# 3             3           3                         XIRCLS
# 4             4           4  Finarkein Analytics Pvt. Ltd.
#
#                                            Job Title  Ratings  \
# 0  Pre-Doctoral Researcher, University Graduate (...      4.5
# 1           .Net C# Developer for a Japanese company      NaN
# 2                                Data Scientist - IT      4.2
# 3                          Machine Learning Engineer      NaN
# 4                          Machine Learning Engineer      NaN
#
#                                      Job Description  Years of Experience  \
# 0    To start the application process  you will n...                  2.0
# 1    About Andaze Japan    Our main business is c...                  3.0
# ...

# %%
import random
c=df3['Level']
i=0
for rows in c:
    if(rows=='Advance'):
        df3['Years of Experience'][i]=random.randint(5, 10)
    i=i+1
# Out:
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_33964\290516164.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Years of Experience'][i]=random.randint(5, 10)

# %%
import random
c=df3['Level']
i=0
for rows in c:
    if(rows=='Mid'):
        df3['Years of Experience'][i]=random.randint(2, 5)
    i=i+1
# Out:
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_12136\2299986718.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Years of Experience'][i]=random.randint(2, 5)

# %%
import random
c=df3['Level']
i=0
for rows in c:
    if(rows=='Entry'):
        df3['Years of Experience'][i]=random.randint(0,1)
    i=i+1
# Out:
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_12136\761358447.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Years of Experience'][i]=random.randint(0,1)

# %%
df3.replace('None', np.nan)
# Out:
#       Unnamed: 0                   Company Name  \
# 0              0                         Google
# 1              1               Procter & Gamble
# 2              2              Andaze Japan Ltd.
# 3              3                         XIRCLS
# 4              4  Finarkein Analytics Pvt. Ltd.
# ...          ...                            ...
# 4118        3190            Aliqan Technologies
# 4119        3191                          Optum
# 4120        3192       Full Potential Solutions
# 4121        3193                      Wise Monk
# 4122        3194                        Genpact
#
#                                               Job Title Ratings salary_period  \
# 0     Pre-Doctoral Researcher, University Graduate (...     4.5          year
# 1              .Net C# Developer for a Japanese company     NaN          year
# 2                                   Data Scientist - IT     4.2         month
# ...

# %%
df3.isna().sum()
# Out:
# Unnamed: 0                0
# Company Name              0
# Job Title                 0
# Ratings                   0
# salary_period          1352
# Average                1352
# Job Description           0
# Years of Experience       0
# Location                  0
# Job Type                  0
# Level                     0
# Categories                0
# dtype: int64

# %%
df3['Salary']=np.nan

# %%
df3.to_csv('red.csv')

# %%
c=df3['salary_period']
i=0
for rows in c:
    if( rows =='year'):
        if(df3['Average'][i]>100):

            df3['Salary'][i]=(df3['Average'][i]/100000)



    i=i+1
# Out:
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_12136\2830108769.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Salary'][i]=(df3['Average'][i]/100000)

# %%
c=df3['salary_period']
i=0
for rows in c:
    if( rows =='month'):
        if(df3['Average'][i]>100):
            df3['Salary'][i]=(df3['Average'][i]*12)/100000




    i=i+1
# Out:
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_12136\1437115630.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Salary'][i]=(df3['Average'][i]*12)/100000

# %%
c=df3['salary_period']
i=0
for rows in c:
    if( rows =='month'):
        if(df3['Average'][i]<100):
            df3['Salary'][i]=(df3['Average'][i]*0.12)




    i=i+1
# Out:
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_12136\4218379358.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Salary'][i]=(df3['Average'][i]*0.12)

# %%
c=df3['salary_period']
i=0
for rows in c:
    if( rows =='hour'):
        df3['Salary'][i]=(df3['Average'][i]*0.0288)




    i=i+1
# Out:
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_12136\3753952091.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Salary'][i]=(df3['Average'][i]*0.0288)

# %%
df3=df3.drop('Unnamed: 0',axis=1)

# %%
df3.to_csv('Proj.csv')
