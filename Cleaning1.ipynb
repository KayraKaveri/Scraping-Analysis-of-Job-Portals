# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import numpy as np
import re

# %%
df= pd.read_csv('k2.csv')
df3=df

# %%
df2=df5
df1=df5

# %%
df2.replace('None', np.nan)
# Out:
#      Unnamed: 0                                       Job Title  \
# 0             0                                 Sr Coal Analyst
# 1             1  Analyst/Senior AnalystAccounting and Reporting
# 2             2                           Business Analyst  TMO
# 3             3                         IND Business Analyst II
# 4             4                                Business Analyst
# ..          ...                                             ...
# 894         894                                 Program Manager
# 895         895                                  Associate, RES
# 896         896           Senior Analyst  Procurement Analytics
# 897         897                         Data Science Sr Analyst
# 898         898                        Sr. Supply Chain Analyst
#
#     Salary Estimate   Job Type  Rating                   Company Name  \
# 0               NaN  Full time     4.0                 Wood Mackenzie
# ...

# %%
df2
# Out:
#      Unnamed: 0                                       Job Title  \
# 0             0                                 Sr Coal Analyst
# 1             1  Analyst/Senior AnalystAccounting and Reporting
# 2             2                           Business Analyst  TMO
# 3             3                         IND Business Analyst II
# 4             4                                Business Analyst
# ..          ...                                             ...
# 894         894                                 Program Manager
# 895         895                                  Associate, RES
# 896         896           Senior Analyst  Procurement Analytics
# 897         897                         Data Science Sr Analyst
# 898         898                        Sr. Supply Chain Analyst
#
#     Salary Estimate   Job Type  Rating                   Company Name  \
# 0               NaN  Full time     4.0                 Wood Mackenzie
# ...

# %%
df2 = df2.dropna(subset=['Job Title'])

# %%
df2=df2.drop_duplicates()

# %%
df2.shape
# Out:
# (899, 11)

# %%
df2.reset_index(drop=True, inplace=True)

# %% [markdown]
# #### Salary

# %%
df2['Salary Estimate'].value_counts()
# Out:
# 1200000  1500000 a year    3
# 240000  480000 a year      2
# 1000000  1500000 a year    2
# Up to 360000 a year        2
# 480000 a year              2
# 600000  900000 a year      2
# 300000  800000 a year      2
# 900000 a year              2
# 1000000  1700000 a year    2
# 500000  1200000 a year     2
# 2100000  3500000 a year    1
# 30000  55000 a month       1
# 20000  30000 a month       1
# 750000  1200000 a year     1
# 30 an hour                 1
# From 33000 a month         1
# From 3200000 a year        1
# 200000  400000 a year      1
# 50000  125000 a year       1
# 1600000  2200000 a year    1
# 2300000 a year             1
# 700000  900000 a year      1
# 150000  500000 a month     1
# 1500000  2500000 a year    1
# 400000  600000 a year      1
# 250000  800000 a year      1
# 300000  500000 a year      1
# 1000000  2000000 a year    1
# 350000  750000 a year      1
# 500000  2500000 a year     1
# 18241  25793 a month       1
# 40000  45000 a month       1
# ...

# %%
df2['Salary Estimate'] = df2['Salary Estimate'].str.replace('\n', '')
df2['Salary Estimate'] = df2['Salary Estimate'].str.replace(',', '')
df2['Salary Estimate'] = df2['Salary Estimate'].str.replace('₹','')

# %%
df2['Salary Estimate'].value_counts()
# Out:
# 1200000  1500000 a year    3
# 240000  480000 a year      2
# 1000000  1500000 a year    2
# Up to 360000 a year        2
# 480000 a year              2
# 600000  900000 a year      2
# 300000  800000 a year      2
# 900000 a year              2
# 1000000  1700000 a year    2
# 500000  1200000 a year     2
# 2100000  3500000 a year    1
# 30000  55000 a month       1
# 20000  30000 a month       1
# 750000  1200000 a year     1
# 30 an hour                 1
# From 33000 a month         1
# From 3200000 a year        1
# 200000  400000 a year      1
# 50000  125000 a year       1
# 1600000  2200000 a year    1
# 2300000 a year             1
# 700000  900000 a year      1
# 150000  500000 a month     1
# 1500000  2500000 a year    1
# 400000  600000 a year      1
# 250000  800000 a year      1
# 300000  500000 a year      1
# 1000000  2000000 a year    1
# 350000  750000 a year      1
# 500000  2500000 a year     1
# 18241  25793 a month       1
# 40000  45000 a month       1
# ...

# %%
df2['salary_period']=np.nan

# %%
import string
df2["Salary Estimate"].str.contains("year")
c=df2["Salary Estimate"]
i=0
for rows in c:
    av=0
    if(type(rows)==str):
        rows=rows.split()
        for item in rows:
            if(item == 'year'):
                df2["salary_period"][i]="year"
        
    i=i+1
# Out:
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_14528\3060545316.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["salary_period"][i]="year"

# %%
import string
df2["Salary Estimate"].str.contains("month")
c=df2["Salary Estimate"]
i=0
for rows in c:
    av=0
    if(type(rows)==str):
        rows=rows.split()
        for item in rows:
            if(item == 'month'):
                df2["salary_period"][i]="month"
        
    i=i+1

# %%
import string
df2["Salary Estimate"].str.contains("hour")
c=df2["Salary Estimate"]
i=0
for rows in c:
    av=0
    if(type(rows)==str):
        rows=rows.split()
        for item in rows:
            if(item == 'hour'):
                df2["salary_period"][i]="hour"
        
    i=i+1

# %%
df2["salary_period"].value_counts()
# Out:
# year     49
# month     9
# hour      1
# Name: salary_period, dtype: int64

# %%
df2.to_csv('k2.csv')

# %%
df2["Salary Estimate"].value_counts()
# Out:
# 1200000  1500000 a year    3
# 240000  480000 a year      2
# 1000000  1500000 a year    2
# Up to 360000 a year        2
# 480000 a year              2
# 600000  900000 a year      2
# 300000  800000 a year      2
# 900000 a year              2
# 1000000  1700000 a year    2
# 500000  1200000 a year     2
# 2100000  3500000 a year    1
# 30000  55000 a month       1
# 20000  30000 a month       1
# 750000  1200000 a year     1
# 30 an hour                 1
# From 33000 a month         1
# From 3200000 a year        1
# 200000  400000 a year      1
# 50000  125000 a year       1
# 1600000  2200000 a year    1
# 2300000 a year             1
# 700000  900000 a year      1
# 150000  500000 a month     1
# 1500000  2500000 a year    1
# 400000  600000 a year      1
# 250000  800000 a year      1
# 300000  500000 a year      1
# 1000000  2000000 a year    1
# 350000  750000 a year      1
# 500000  2500000 a year     1
# 18241  25793 a month       1
# 40000  45000 a month       1
# ...

# %%
df2["Average"]=np.nan

# %%
c=df2["Salary Estimate"]

av=0
a=0
b=0
i=0
for rows in c:
    av=0
    if(type(rows)==str):
        rows=rows.split()
        for item in rows:
            
            if(item.isdigit()):
                av=av+1
    if(av==1):
        for char in rows:
            if(char.isdigit()):
                df2["Average"][i]=char               
    i=i+1
# Out:
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_22824\82638905.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Average"][i]=char

# %%
df2['Salary Estimate'] = df2['Salary Estimate'].str.replace('-','')

# %%
def avg(a,b):
    return (a+b)/2
c=df2["Salary Estimate"]

av=0
a=0
b=0
i=0
for rows in c:
    if(type(rows)==str):
        rows=rows.split()
        for item in range(0,len(rows)):
            if(rows[item].isdigit() and rows[item+1].isdigit()):
                av=avg(int(rows[0]),int(rows[1]))
                df2["Average"][i]=av
    i=i+1
# Out:
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_22824\191633000.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Average"][i]=av

# %%
df2["Average"].value_counts()
# Out:
# 1350000.0    6
# 550000.0     3
# 480000       2
# 1500000.0    2
# 42500.0      2
# 850000.0     2
# 360000.0     2
# 1250000.0    2
# 360000       2
# 350000.0     2
# 900000       2
# 750000.0     2
# 2300000      1
# 3200000      1
# 300000.0     1
# 1900000.0    1
# 500000.0     1
# 325000.0     1
# 2800000.0    1
# 87500.0      1
# 800000.0     1
# 33000        1
# 975000.0     1
# 2000000.0    1
# 525000.0     1
# 30           1
# 1050000.0    1
# 22017.0      1
# 1000000      1
# 873077.0     1
# 5000         1
# 1400000.0    1
# 2150000.0    1
# 2250000.0    1
# 25000.0      1
# 550000       1
# 37500.0      1
# 35000.0      1
# 2500000.0    1
# 400000       1
# 400000.0     1
# 1080486.0    1
# Name: Average, dtype: int64

# %% [markdown]
# #### Years of Experience

# %%
def desc(i):
    l = df2["Job Description"][i]
    p = l.split('\n')
    return p

# %%
exp=[]

# %%
for i in range(0,899):
    p=desc(i)
    for line in p:
        y = re.findall('\d+ .+ [Ee]xperience', line)
        if y!= []:
            exp.append(y)

# %%
len(exp)
# Out:
# 833

# %%
exp2 = pd.DataFrame(exp)

# %%
exp2.shape
# Out:
# (833, 1)

# %%
df2["Years of Experience"]=exp2

# %%
df2["Years of Experience"].value_counts()
# Out:
# 3 to 5 years of experience  Demonstrate knowledge on Loss reserve discounting   Unearned premiums  Demonstrate understanding of GAAP to STAT adjustments  Experience in preparation review of 1120 1120PC  1120L  831  b  captives  953  d  returns  Working knowledge on the regular and mixed group consolidation  Good knowledge on the software’s like OneSource income tax or corporate tax   Technical experience in working on US Insurance Companies Tax Provision work  Property and Casualty Life Health   Experience working on US Domestic or US Insurance State and Local Tax  SALT  Filing    Ideally  you’ll also have   Awareness of other taxes in the US  Ability to read  interpret and apply the tax legislation   What we look for  We are looking for experience                                                                                                                                                                                                                                                
# ...

# %%
c=exp2[0]
i=0
d=0
k=[]
for rows in c:
    
    if(type(rows)==str):
        rows=rows.lower()
        rows=rows.split()
        
        a='years'
        c='year'
        b='experience'
        if (a in rows or c in rows) and b in rows:
            for t in range(0,len(rows)):
                if(rows[t].isdigit()):
                    if(int(rows[t])<=20):                
                        if(rows[t+1]=='years' or rows[t+1]=='year' or rows[t-1]=='year' or rows[t-1]=='years'):
                            exp2[0][i]=int(rows[t])
                    else:
                        exp2[0][i]=None
        else:
            exp2[0][i]=None
            
    i=i+1

# %%
c=exp2[0]
i=0
d=0
k=[]
for rows in c:
    
    if(type(rows)==str):
        rows=rows.lower()
        rows=rows.split()
        
        a='years'
        c='year'
        b='experience'
        if (a in rows or c in rows) and b in rows:
            for t in range(0,len(rows)):
                if(rows[t].isdigit()):
                    if(int(rows[t])<=20):                
                        if(rows[t+2]=='years' or rows[t+2]=='year' ):
                            exp2[0][i]=int(rows[t])
                    else:
                        exp2[0][i]=None
        else:
            exp2[0][i]=None
            
    i=i+1

# %%
c=df2["Years of Experience"]
av=[]
a=0
b=0
i=0
for rows in c:
    if(type(rows)==str):
        rows=rows.lower()
        rows=rows.split()
        a='years'
        b='experience'
        if a in rows and b in rows:
            for item in rows:
                if(item.isdigit()):
                    if(int(item) <=20):
                        df2["Years of Experience"][i]=item
                    else:
                        df2["Years of Experience"][i]=None
        else:
            df2["Years of Experience"][i]=None
    i=i+1
# Out:
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_22824\2225742907.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Years of Experience"][i]=None
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_22824\2225742907.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Years of Experience"][i]=item
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_22824\2225742907.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
exp2
# Out:
#         0
# 0    None
# 1    None
# 2       3
# 3       3
# 4    None
# ..    ...
# 828     5
# 829  None
# 830     8
# 831     5
# 832    10
#
# [833 rows x 1 columns]

# %% [markdown]
# #### Job Type

# %%
df2["Job Title"].value_counts()
# Out:
# Data Analyst                   23
# Business Analyst               21
# Data Engineer                   9
# Analyst                         8
# Senior Data Analyst             8
#                                ..
# SIEM                            1
# Process Engineering Analyst     1
# Sr Software Engineer, API       1
# Software Engineer  JAVA FSD     1
# Sr. Supply Chain Analyst        1
# Name: Job Title, Length: 738, dtype: int64

# %%
df2["Job Type"].value_counts()
# Out:
# Full time    895
# Part time      4
# Name: Job Type, dtype: int64

# %%
df2=df2.drop(['Unnamed: 0'],axis=1)

# %%
df2=df2.drop(['Job Snippet'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [240], line 1
# ----> 1 df2=df2.drop(['Job Snippet'],axis=1)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:5391, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5243 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
# ...

# %%
df2=df2.drop(['Links'],axis=1)

# %%
df2=df2.drop(['Job Description'],axis=1)

# %%
df2.isna().sum()

# %%
df2['Job Type'] = df2['Job Type'].str.replace('\n', '')
df2['Job Type'] = df2['Job Type'].str.replace(',', '')
df2['Job Type'] = df2['Job Type'].str.replace('₹', '')

# %%
df2['Job Type'] = df2['Job Type'].str.replace("/", '')

# %%
df2['Job Type'] = df2['Job Type'].str.replace("'", '')

# %%
df2['Job Type'] = df2['Job Type'].str.replace('-', '')

# %%
df2["Job Shift"]=np.nan

# %%
df3= pd.read_csv('wwww.csv')

# %%
def avg(a,b):
    return (a+b)/2
c=df2["Salary Estimate"]

av=0
a=0
b=0
i=0
for rows in c:
    if(type(rows)==str):
        rows=rows.split()
        for item in range(0,len(rows)):
            if(rows[item].isdigit() and rows[item+1].isdigit()):
                av=avg(int(rows[0]),int(rows[1]))
                df2["Average"][i]=av
    i=i+1

# %%
df2['Job Type'].value_counts()

# %%
kk=[]
c=df2["Job Title"]
for rows in c:
    if(type(rows)==str):
        df2['Job Type']='Full time'

# %%
df2['Job Type'].value_counts()

# %%
df2

# %%
c=df3["Years of Experience"]
av=[]
a=0
b=0
i=0
for rows in c:
    if(type(rows)==str):
        rows=rows.lower()
        rows=rows.split()
        a='years'
        b='experience'
        if a in rows and b in rows:
            for item in rows:
                if(item.isdigit()):
                    if(int(item) <=20):
                        df3["Years of Experience"][i]=item
                    else:
                        df3["Years of Experience"][i]=None
        else:
            df3["Years of Experience"][i]=None
    i=i+1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [241], line 1
# ----> 1 c=df3["Years of Experience"]
#       2 av=[]
#       3 a=0
#
# NameError: name 'df3' is not defined

# %%
df3["Years of Experience"]
# Out:
# 0        10
# 1      None
# 2         2
# 3         3
# 4      None
#        ...
# 894       5
# 895       5
# 896       5
# 897      10
# 898      10
# Name: Years of Experience, Length: 899, dtype: object

# %%
df3["Years of Experience"].value_counts()
# Out:
# 5     136
# 3     118
# 2      88
# 4      79
# 6      67
# 8      63
# 7      63
# 10     47
# 1      21
# 9      15
# 12     14
# 15     12
# 13      4
# 11      3
# 10      1
# 20      1
# 14      1
# Name: Years of Experience, dtype: int64

# %%
df2.to_csv('first.csv')

# %%
df3
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 0               0           0
# 1               1           1
# 2               2           2
# 3               3           3
# 4               4           4
# ..            ...         ...
# 894           894         894
# 895           895         895
# 896           896         896
# 897           897         897
# 898           898         898
#
#                                            Job Title Salary Estimate  \
# 0                                    Sr Coal Analyst             NaN
# 1    Analyst/Senior Analyst-Accounting and Reporting             NaN
# 2                             Business Analyst - TMO             NaN
# 3                            IND Business Analyst II             NaN
# 4                                   Business Analyst             NaN
# ..                                               ...             ...
# 894                                  Program Manager   900000 a year
# ...

# %%
df3=df3.drop(['Unnamed: 0.1'],axis=1)

# %%
df3=df3.drop(['Unnamed: 0'],axis=1)

# %%
df3=df3.drop(['Salary Estimate'],axis=1)

# %%
df3
# Out:
#                                            Job Title   Job Type  Rating  \
# 0                                    Sr Coal Analyst  Full time     4.0
# 1    Analyst/Senior Analyst-Accounting and Reporting  Full time     3.9
# 2                             Business Analyst - TMO  Full time     3.9
# 3                            IND Business Analyst II  Full time     3.1
# 4                                   Business Analyst  Full time     3.6
# ..                                               ...        ...     ...
# 894                                  Program Manager  Full time     3.5
# 895                                   Associate, RES  Full time     3.7
# 896           Senior Analyst - Procurement Analytics  Full time     4.0
# 897                          Data Science Sr Analyst  Full time     3.8
# 898                         Sr. Supply Chain Analyst  Full time     3.8
#
#                       Company Name              Location Years of Experience  \
# ...

# %%
df3['Job Title'].value_counts()
# Out:
# Data Analyst                   23
# Business Analyst               21
# Data Engineer                   9
# Analyst                         8
# Senior Data Analyst             8
#                                ..
# SIEM                            1
# Process Engineering Analyst     1
# Sr Software Engineer, API       1
# Software Engineer  JAVA FSD     1
# Sr. Supply Chain Analyst        1
# Name: Job Title, Length: 738, dtype: int64
