# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import numpy as np
import re
import math

# %%
df= pd.read_csv('glass10.csv')

# %%
df2=df
df3=df

# %%
df.shape
# Out:
# (930, 13)

# %%
df['Job Title'].value_counts()
# Out:
# Machine Learning Engineer                                                        496
# Machine Learning Intern                                                           62
# Pre-Doctoral Researcher, University Graduate (Fixed-Term Contract) 2023 Start     31
# .Net C# Developer for a Japanese company                                          31
# Data Scientist - IT                                                               31
# Python Machine Learning Engineer                                                  31
# Machine learning Engineer                                                         31
# Data Engineer, Machine Learning                                                   31
# Jr./ Sr. Machine Learning Developer                                               31
# Machine learning, Machine Engineer                                                31
# Data Analyst                                                                      31
# ...

# %%
df['Categories']=np.nan

# %%
c=df['Job Title']
a='scientist'
b='science'
i=0

for rows in c:
    rows=rows.lower()
    if( a in rows or b in rows):
        df['Categories'][i]='Data Scientist'
    i=i+1
# Out:
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_15840\3014737064.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Categories'][i]='Data Scientist'

# %%
df['Categories'].value_counts()
# Out:
# Data Scientist    62
# Name: Categories, dtype: int64

# %%
c=df['Job Title']
a='analytics'
b='analyst'
i=0

for rows in c:
    rows=rows.lower()
    if( b in rows or a in rows):
        if(type(df['Categories'][i])==float):
            df['Categories'][i]='Data Analyst'
    i=i+1

# %%
c=df['Job Title']
a='engineer'
b='engineering'

i=0

for rows in c:
    rows=rows.lower()
    if( a in rows or b in rows ):
        df['Categories'][i]='Data Engineer'
    i=i+1

# %%
c=df['Job Title']
a='developer'
i=0

for rows in c:
    rows=rows.lower()
    if( a in rows  ):
        if(type(df['Categories'][i])==float):
            df['Categories'][i]='Developer'
    i=i+1

# %%
c=df['Job Title']
a='architect'
i=0

for rows in c:
    rows=rows.lower()
    if( a in rows  ):
        if(type(df['Categories'][i])==float):
            df['Categories'][i]='Architect'

    i=i+1

# %%
c=df['Job Title']
a='consultant'
i=0

for rows in c:
    rows=rows.lower()
    if( a in rows  ):
        if(type(df['Categories'][i])==float):
            df['Categories'][i]='Consultant'

    i=i+1

# %%
c=df['Job Title']

b='deep learning'
i=0

for rows in c:
    rows=rows.lower()
    if( b in rows ):
        df['Categories'][i]='AI Specialist'

    i=i+1

# %%
c=df['Job Title']

b='nlp'
i=0

for rows in c:
    rows=rows.lower()
    if( b in rows ):
        df['Categories'][i]='AI Specialist'

    i=i+1

# %%
c=df['Job Title']
a='artificial intelligence'
b='ai'
i=0

for rows in c:
    rows=rows.lower()
    if( a in rows or b in rows ):
        df['Categories'][i]='AI Specialist'

    i=i+1

# %%
c=df['Job Title']
a='machine learning'
b='ml'

i=0

for rows in c:
    rows=rows.lower()

    if( a in rows or b in rows  ):
        df['Categories'][i]='AI Specialist'

    i=i+1

# %%
c=df['Job Title']
a='statistical'
b='biostatistician'

i=0

for rows in c:
    rows=rows.lower()

    if( a in rows or b in rows  ):
        if(type(df['Categories'][i])==float):
            df['Categories'][i]='Statiticians/Research'

    i=i+1

# %%
c=df['Job Title']
a='research'


i=0

for rows in c:
    rows=rows.lower()

    if( a in rows or b in rows  ):
        if(type(df['Categories'][i])==float):
            df['Categories'][i]='Statiticians/Research'

    i=i+1

# %%
c=df['Job Title']
a='big data'
i=0

for rows in c:
    rows=rows.lower()
    if( a in rows  ):
        df['Categories'][i]='Big Data Analyst'

    i=i+1

# %%
c=df['Job Title']
a='warehousing'
i=0

for rows in c:
    rows=rows.lower()
    if( a in rows  ):
        df['Categories'][i]='AI Specialist'

    i=i+1

# %%
c=df['Job Title']
a='data'
i=0

for rows in c:

    rows=rows.lower()

    if( a in rows  ):
        if(type(df['Categories'][i])==float):
            df['Categories'][i]='Data Base Management'

    i=i+1

# %%
c=df['Job Title']
a='dba'
i=0

for rows in c:

    rows=rows.lower()

    if( a in rows  ):
        if(type(df['Categories'][i])==float):
            df['Categories'][i]='Data Base Management'

    i=i+1

# %%
c=df['Job Title']
a='kafka'
b='pyspark'
c='spark'
i=0

for rows in c:

    rows=rows.lower()

    if( a in rows  ):
        df['Categories'][i]='Big Data Analyst'

    i=i+1

# %%
c=df['Job Title']
a='business'
i=0

for rows in c:

    rows=rows.lower()

    if( a in rows  ):
        if(type(df['Categories'][i])==float):
            df['Categories'][i]='Business Analytics'

    i=i+1

# %%
c=df['Categories']

i=0

for rows in c:
    if(type(rows)==float):
        df.drop(i,inplace=True)



    i=i+1

# %%
df
# Out:
#      Unnamed: 0.1  Unnamed: 0                             Company Name  \
# 0               0           0                                   Google
# 1               1           1                         Procter & Gamble
# 2               2           2                        Andaze Japan Ltd.
# 3               3           3                                   XIRCLS
# 4               4           4            Finarkein Analytics Pvt. Ltd.
# ..            ...         ...                                      ...
# 925           925         925                                      SAP
# 926           926         926  NeuranceAI Technologies Private Limited
# 927           927         927                     Alpha Net Consulting
# 928           928         928                      Predictive Research
# 929           929         929                                 INKRONIX
#
#                                              Job Title Job Tocation Ratings  \
# ...

# %%
df=df.drop('Unnamed: 0',axis=1)

# %%
df.to_csv('abc.csv')

# %%
df['Level']=np.nan

# %%
df['Job Title'].value_counts()
# Out:
# Data Scientist                                         370
# Data Analyst                                           180
# Business Analyst                                        82
# Data scientist                                          65
# Data Science Intern                                     64
#                                                       ...
# Senior Engineer, Automation Development Engineering      1
# Software Engineer 2                                      1
# Sr Analyst                                               1
# Sr Analyst ACE                                           1
# Supply Chain Network Data & Analytics Specialist         1
# Name: Job Title, Length: 1253, dtype: int64

# %%
df.shape
# Out:
# (3628, 12)

# %%
df['Level'].value_counts()
# Out:
# Advance    348
# Name: Level, dtype: int64

# %%
len(df['Job Title'])
# Out:
# 3593

# %%
type(df['Level'][0])
# Out:
# numpy.float64

# %%
c=df['Job Title']
z=0

for rows in c:
    rows=rows.lower()
    a='senior'
    if(a in rows ):
        df.loc[z,'Level']='Advance'



    z=z+1

# %%
df
# Out:
#       Unnamed: 0                      Company Name  \
# 0            0.0  Larsen & Toubro Infotech Limited
# 1            1.0                          Deloitte
# 2            2.0         Flairmid Software Pvt Ltd
# 3            3.0                             Shell
# 4            4.0    Brimming Grace Capital Pvt Ltd
# ...          ...                               ...
# 2332         NaN                               NaN
# 2359         NaN                               NaN
# 2435         NaN                               NaN
# 2567         NaN                               NaN
# 2606         NaN                               NaN
#
#                                               Job Title salary_period  \
# 0                                          Data Science          year
# 1     Senior Analyst- Research & Insights- Data Scie...          year
# 2                                 Junior Data Scientist          year
# ...

# %%
c=df['Job Title']
z=0

for rows in c:
    rows=rows.lower()
    a='sr'
    if(a in rows ):
        df.loc[z,'Level']='Advance'



    z=z+1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [373], line 5
#       2 z=0
#       4 for rows in c:
# ----> 5     rows=rows.lower()
#       6     a='sr'
#       7     if(a in rows ):
#
# AttributeError: 'float' object has no attribute 'lower'

# %%
c=df['Job Title']
z=0

for rows in c:
    rows=rows.lower()
    a='senior'
    b='sr'
    c='chief'
    d='dir'
    e='director'
    f='jr'
    g='junior'
    h='intern'
    i='internship'
    j='trainee'
    k='trainer'
    l='associate'
    m='fresh'
    n='fresher'
    if(a in rows or b in rows or c in rows or d in rows or e in rows):
        df['Level'][z]='Advanced'
    elif(f in rows or g in rows or h in rows or i in rows or j in rows or k in rows or l in rows or m in rows or n in rows):
        df['Level'][z]='Entry'
    else:
        df['Level'][z]='Mid'
    z=z+1
# Out:
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_35528\3505097531.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Level'][z]='Mid'
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_35528\3505097531.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Level'][z]='Advanced'
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_35528\3505097531.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Level'][z]='Entry'
# ...

# %%
df['Level'].value_counts()
# Out:
# Mid    1
# Name: Level, dtype: int64

# %%
df.isna().sum()
# Out:
# Unnamed: 0                0
# Company Name              0
# Job Title                 0
# salary_period          1658
# Average                1658
# Job Description           0
# Years of Experience    2031
# Location                123
# Job Type                  0
# Rating                    0
# Categories                0
# Level                   139
# dtype: int64

# %%
c=df['Level']

i=0
k=0
for rows in c:
    if(type(rows)==np.float64):
        print(df['Job Title'][i])
        k=k+1


    i=i+1
print(k)
# Out:
# 0
