# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import numpy as np
import re

# %%
df= pd.read_csv('finalglassdoor1.csv')

# %%
df
# Out:
#      Unnamed: 0                      Company Name  \
# 0             0  Larsen & Toubro Infotech Limited
# 1             1                          Deloitte
# 2             2         Flairmid Software Pvt Ltd
# 3             3                             Shell
# 4             4    Brimming Grace Capital Pvt Ltd
# ..          ...                               ...
# 894         895                           L'Oreal
# 895         896              Alpha Net Consulting
# 896         897                              Visa
# 897         898             prwatech technologies
# 898         899       Tanishq Enterprises pvt ltd
#
#                                              Job Title  Ratings salary_period  \
# 0                                         Data Science      3.8          year
# 1    Senior Analyst- Research & Insights- Data Scie...      4.1          year
# 2                                Junior Data Scientist      4.2          year
# ...

# %%
df2= pd.read_csv('finalglassdoor2.csv')

# %%
df2
# Out:
#      Unnamed: 0                        Company Name  \
# 0             0                             Telstra
# 1             1                             Arcadis
# 2             2                              Exusia
# 3             3         Sweans Technologies Pvt Ltd
# 4             4                        24-7 Intouch
# ..          ...                                 ...
# 925         925      TATA Consultancy Services Ltd.
# 926         926                           TMF Group
# 927         927     ANI Calls India Private Limited
# 928         928     ANI Calls India Private Limited
# 929         929  Genie Customer Management Services
#
#                                              Job Title  Ratings salary_period  \
# 0                                         Data Analyst      3.9          year
# 1                             Data Engineering Analyst      3.9          year
# 2     Senior Data Analyst - Data Engineering/Analytics      3.9          year
# ...

# %%
df2=df2.drop(['Unnamed: 0'],axis=1)

# %%
df=df.drop(['Unnamed: 0'],axis=1)

# %%
frames=[df,df2]

# %%
df3 = pd.concat(frames)

# %%
display(df3)
# Out:
#                            Company Name  \
# 0      Larsen & Toubro Infotech Limited
# 1                              Deloitte
# 2             Flairmid Software Pvt Ltd
# 3                                 Shell
# 4        Brimming Grace Capital Pvt Ltd
# ..                                  ...
# 925      TATA Consultancy Services Ltd.
# 926                           TMF Group
# 927     ANI Calls India Private Limited
# 928     ANI Calls India Private Limited
# 929  Genie Customer Management Services
#
#                                              Job Title  Ratings salary_period  \
# 0                                         Data Science      3.8          year
# 1    Senior Analyst- Research & Insights- Data Scie...      4.1          year
# 2                                Junior Data Scientist      4.2          year
# 3                             Associate Data Scientist      4.1          year
# 4                                Data Scientist Intern      4.2          year
# ...

# %%
df3.to_csv('Glassdoor.csv')

# %%
df3.shape
# Out:
# (1829, 9)

# %%
df3 = df3.dropna(subset=['Job Title'])

# %%
df3['Job Title'].value_counts()
# Out:
# Data Scientist                                                                                          239
# Data Analyst                                                                                            155
# Business Analyst                                                                                         62
# Data Science Intern                                                                                      60
# Associate Data Scientist                                                                                 60
# Data scientist                                                                                           60
# Business Analyst (BA) - Banking - WFH                                                                    31
# Project Business Analyst                                                                                 31
# Reporting Analyst                                                                                        31
# ...

# %%
c=df3['Job Title']
s=0
i=0
for rows in c:
    if(rows == 'Data Analyst -WAKAD-Pune sal: 2LPA to 4LPA Exp:0-3yrsAssociated with US Financial Investment clients'):
        df3['Years of Experience'][i]=3
    i=i+1
# Out:
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_8752\849177708.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Years of Experience'][i]=3
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_8752\849177708.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Years of Experience'][i]=3
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_8752\849177708.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
c=df3['Job Title']
s=0
i=0
for rows in c:
    if(rows == 'Operations Analyst, Trilogy (Remote) - $30,000/year USD'):
        df3['Average'][i]=24
        s=s+1
    i=i+1
print(s)
# Out:
# 31
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_8752\3221779530.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Average'][i]=24
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_8752\3221779530.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Average'][i]=24
# C:\Users\Kaveri\AppData\Local\Temp\ipykernel_8752\3221779530.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Average'][i]=24
# ...

# %%
s
# Out:
# 31

# %%
df3['Years of Experience'].value_counts()
# Out:
# 2.0     123
# 3.0      93
# 6.0      60
# 12.0     31
# 4.0      31
# 1.0      30
# 5.0      30
# 8.0      30
# Name: Years of Experience, dtype: int64

# %%
df3['Average'].value_counts()
# Out:
# 5.000      161
# 6.500      136
# 6.000      124
# 15.000     100
# 3.500       97
# 2.500       96
# 10.000      70
# 13.000      69
# 4.000       69
# 11.000      66
# 9.500       65
# 13.500      64
# 11.500      62
# 10.500      35
# 4.500       35
# 807.695     35
# 2.000       35
# 30.000      34
# 21.500      34
# 80.000      34
# 7.000       34
# 8.000       31
# 27.500      31
# 20.500      31
# 28.000      31
# 46.500      31
# 29.000      31
# 14.000      31
# 5.500       31
# 3.000       31
# 12.000       1
# 24.000       1
# Name: Average, dtype: int64

# %%
df3['salary_period'].value_counts()
# Out:
# year     1442
# month     259
# hour       35
# Name: salary_period, dtype: int64

# %%
df3.to_csv('Glassdoor.csv')
